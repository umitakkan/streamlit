# %%
import dearpygui.dearpygui as dpg
import sys, os, json, re
sys.path.append(r'C:\Users\umita\Desktop\Pythonx')
from umit_pylib import DB
from umit_pylib import df_lib as ME
from datetime import datetime as dtt
import pandas as pd, numpy as np, matplotlib.pyplot as plt
db = DB.create()

sec_list =  list(db.get_list('SEC'))

dpg.create_context()
try:
    for al in dpg.get_aliases():        dpg.delete_item(al)
    for sec in sec_list:     dpg.delete_item(sec)
except:
    pass

def change_text(sender, app_data):
    dpg.set_value("text_item", f"{sender} Mouse Button ID: {app_data}")
    #dpg.set_value('sec_txt', sender)

def callback(sender, filter_string):
    if sender == 'sec_txt':
        dpg.configure_item(ppp,show=True)
        dpg.set_value("filter_id", filter_string) 
        dpg.focus_item('sec_txt')
    else:
        dpg.configure_item(ppp,show=False)
        dpg.set_value('sec_txt', filter_string[1])
        
with dpg.handler_registry(show=True, tag="__demo_keyboard_handler"):
    k_press = dpg.add_key_press_handler(key=-1)
def _event_handler(sender, data):
    type=dpg.get_item_info(sender)["type"]
    if type=="mvAppItemType::mvKeyPressHandler":
        newsec_list = [idx for idx in sec_list if idx.startswith(chr(data))]
        dpg.configure_item('combo', items=newsec_list)
dpg.set_item_callback(k_press, _event_handler)


with dpg.window(label="about", width =500, height=300):
    dpg.add_combo(items=sec_list, label='combo', default_value=sec_list[0], width=200, tag='combo',
                 callback=lambda: dpg.configure_item("__demo_keyboard_handler", show=True))

    dpg.add_input_text(label='    ', tag='output')
    dpg.add_input_text(label="Filter", tag='sec_txt', width=100, uppercase=True, 
                       no_spaces=True, callback=callback)  
    with dpg.popup(parent=dpg.last_item()) as ppp:
        with dpg.filter_set(id="filter_id"):
            for sec in sec_list:
                dpg.add_text(sec, filter_key=sec, bullet=False, tag=sec)
                with dpg.item_handler_registry(tag=sec+"_widget_handler"):
                    dpg.add_item_clicked_handler(callback=callback)
                dpg.bind_item_handler_registry(sec, sec+"_widget_handler") 
    """         
    with dpg.window(label='chld', show=False, no_focus_on_appearing = False, 
                    no_bring_to_front_on_focus=False, no_background=True, 
                    no_title_bar=True, no_scrollbar=True, pos=dpg.get_item_pos('sec_txt')) as ppp:
        with dpg.filter_set(id="filter_id"):
            for sec in sec_list:
                dpg.add_text(sec, filter_key=sec, bullet=False, tag=sec)
                with dpg.item_handler_registry(tag=sec+"_widget_handler"):
                    dpg.add_item_clicked_handler(callback=callback)
                dpg.bind_item_handler_registry(sec, sec+"_widget_handler") 

    """   
dpg.create_viewport(title='Custom Title', width=600, height=200)
dpg.setup_dearpygui();dpg.show_viewport();dpg.start_dearpygui();dpg.destroy_context()
# Out:
# 'combo'
# 'output'
# 'sec_txt'
# 'ACSEL.E'
# 33
# 'ADEL.E'
# 36
# 'ADESE.E'
# 39
# 'AEFES.E'
# 42
# 'AFYON.E'
# 45
# 'AGESA.E'
# 48
# 'AGHOL.E'
# 51
# 'AGYO.E'
# 54
# 'AKBNK.E'
# 57
# 'AKCNS.E'
# 60
# 'AKENR.E'
# 63
# 'AKFGY.E'
# 66
# 'AKGRT.E'
# 69
# 'AKMGY.E'
# 72
# 'AKSA.E'
# 75
# 'AKSEN.E'
# 78
# 'AKSGY.E'
# 81
# 'AKSUE.E'
# 84
# 'AKYHO.E'
# 87
# 'ALARK.E'
# 90
# 'ALBRK.E'
# 93
# 'ALCAR.E'
# 96
# 'ALCTL.E'
# 99
# 'ALGYO.E'
# 102
# 'ALKA.E'
# 105
# 'ALKIM.E'
# 108
# 'ALMAD.E'
# 111
# 'ANELE.E'
# 114
# 'ANGEN.E'
# 117
# 'ANHYT.E'
# 120
# 'ANSGR.E'
# 123
# 'ARASE.E'
# 126
# 'ARCLK.E'
# 129
# 'ARDYZ.E'
# 132
# 'ARENA.E'
# 135
# 'ARMDA.E'
# 138
# 'ARSAN.E'
# 141
# 'ARZUM.E'
# 144
# 'ASELS.E'
# 147
# 'ASUZU.E'
# 150
# 'ATAGY.E'
# 153
# 'ATATP.E'
# 156
# 'ATEKS.E'
# 159
# 'ATLAS.E'
# 162
# 'ATSYH.E'
# 165
# 'AVGYO.E'
# 168
# 'AVHOL.E'
# 171
# 'AVOD.E'
# 174
# 'AVTUR.E'
# 177
# 'AYCES.E'
# 180
# 'AYDEM.E'
# 183
# 'AYEN.E'
# 186
# 'AYES.E'
# 189
# 'AYGAZ.E'
# 192
# 'BAGFS.E'
# 195
# ...

# %%
sec_list
newsec_list = [idx for idx in sec_list if idx.lower().startswith(chr(65))]
newsec_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15140\3151737615.py in <module>
# ----> 1 newsec_list = [idx for idx in sec_list if idx.startswith(chr(65))]
#       2 newsec_list
#
# NameError: name 'sec_list' is not defined

# %%
dpg.create_context()

with dpg.window(label="Tutorial"):

    # configuration set when button is created
    dpg.add_button(label="Apply", width=300)

    # user data and callback set any time after button has been created
    btn = dpg.add_button(label="Apply 2")
    dpg.set_item_label(btn, "Button 57")
    dpg.set_item_width(btn, 200)

dpg.show_item_registry()

dpg.create_viewport(title='Custom Title', width=600, height=200)
dpg.setup_dearpygui();dpg.show_viewport();dpg.start_dearpygui();dpg.destroy_context()
# Out:
# 26

# %%
import dearpygui.dearpygui as dpg

dpg.create_context()

try:
    for al in dpg.get_aliases():        dpg.delete_item(al)
    for sec in sec_list:     dpg.delete_item(sec)
except:
    pass

def callback(sender, app_data):
    if sender == 'sec_txt':
        dpg.configure_item(ppp,show=True)
        dpg.set_value("filter_id", app_data) 
        dpg.focus_item('sec_txt')
    else:
        dpg.configure_item(ppp,show=False)
        dpg.set_value('sec_txt', app_data[1])
with dpg.window(label="about", width =500, height=300) as main_w:   
    dpg.add_input_text(label="Filter", tag='sec_txt', uppercase=True, callback=callback)  
    
    with dpg.window(label='chld', show=False, no_focus_on_appearing = False, 
                    no_bring_to_front_on_focus=False, no_background=True, 
                    no_title_bar=True, no_scrollbar=True, pos=(200,200)) as ppp:
        with dpg.filter_set(id="filter_id"):
            for sec in sec_list:
                dpg.add_text(sec, filter_key=sec, bullet=False, tag=sec)
                with dpg.item_handler_registry(tag=sec+"_widget_handler"):
                    dpg.add_item_clicked_handler(callback=callback)
                dpg.bind_item_handler_registry(sec, sec+"_widget_handler")  
    
dpg.create_viewport(title='Custom Title', width=600, height=200)
dpg.setup_dearpygui();dpg.show_viewport();dpg.start_dearpygui();dpg.destroy_context()
# Out:
# 'sec_txt'
# 'ACSEL.E'
# 27
# 'ADEL.E'
# 30
# 'ADESE.E'
# 33
# 'AEFES.E'
# 36
# 'AFYON.E'
# 39
# 'AGESA.E'
# 42
# 'AGHOL.E'
# 45
# 'AGYO.E'
# 48
# 'AKBNK.E'
# 51
# 'AKCNS.E'
# 54
# 'AKENR.E'
# 57
# 'AKFGY.E'
# 60
# 'AKGRT.E'
# 63
# 'AKMGY.E'
# 66
# 'AKSA.E'
# 69
# 'AKSEN.E'
# 72
# 'AKSGY.E'
# 75
# 'AKSUE.E'
# 78
# 'AKYHO.E'
# 81
# 'ALARK.E'
# 84
# 'ALBRK.E'
# 87
# 'ALCAR.E'
# 90
# 'ALCTL.E'
# 93
# 'ALGYO.E'
# 96
# 'ALKA.E'
# 99
# 'ALKIM.E'
# 102
# 'ALMAD.E'
# 105
# 'ANELE.E'
# 108
# 'ANGEN.E'
# 111
# 'ANHYT.E'
# 114
# 'ANSGR.E'
# 117
# 'ARASE.E'
# 120
# 'ARCLK.E'
# 123
# 'ARDYZ.E'
# 126
# 'ARENA.E'
# 129
# 'ARMDA.E'
# 132
# 'ARSAN.E'
# 135
# 'ARZUM.E'
# 138
# 'ASELS.E'
# 141
# 'ASUZU.E'
# 144
# 'ATAGY.E'
# 147
# 'ATATP.E'
# 150
# 'ATEKS.E'
# 153
# 'ATLAS.E'
# 156
# 'ATSYH.E'
# 159
# 'AVGYO.E'
# 162
# 'AVHOL.E'
# 165
# 'AVOD.E'
# 168
# 'AVTUR.E'
# 171
# 'AYCES.E'
# 174
# 'AYDEM.E'
# 177
# 'AYEN.E'
# 180
# 'AYES.E'
# 183
# 'AYGAZ.E'
# 186
# 'BAGFS.E'
# 189
# 'BAKAB.E'
# 192
# 'BALAT.E'
# ...

# %%
import dearpygui.dearpygui as dpg

dpg.create_context()

dpg.create_viewport(title="DearBagPlayer", width=1500, height=900, x_pos=0, y_pos=0)
def eventHandler(self, sender, data):
    # KeyDown data = [key, seconds]; KeyRelease data = key
    event_type = dpg.get_item_info(sender)["type"]
    # print(data, type(data))
    if event_type == "mvAppItemType::mvKeyDownHandler" and data[0] == dpg.mvKey_Control:
        self.xy_plot_enabled = True
        # print("XY Pos Enabled!")
    elif event_type == "mvAppItemType::mvKeyReleaseHandler" and data == dpg.mvKey_Control:
        self.xy_plot_enabled = False
        # print("XY Pos Disabled!")
    if event_type == "mvAppItemType::mvKeyDownHandler" and data[0] == dpg.mvKey_Shift:
        self.s_length_plot_enabled = True
        # print("S length plot Enabled!")
    elif event_type == "mvAppItemType::mvKeyReleaseHandler" and data == dpg.mvKey_Shift:
        self.s_length_plot_enabled = False
        # print("S length plot Disabled!")
# Viewport menu bar
with dpg.file_dialog(directory_selector=False, show=False, file_count=10) as file_dialog_tag:
    dpg.add_file_extension(".*")
    dpg.add_file_extension("", color=(150, 255, 150, 255))
    dpg.add_file_extension("Source files (*.cpp *.h *.hpp){.cpp,.h,.hpp}", color=(0, 255, 255, 255))
    dpg.add_file_extension(".h", color=(255, 0, 255, 255), custom_text="[header]")
    dpg.add_file_extension(".py", color=(0, 255, 0, 255), custom_text="[Python]")
    dpg.add_file_extension(".bag", color=(0, 255, 0, 255), custom_text="[rosbag]")

with dpg.viewport_menu_bar():
    with dpg.menu(label="Files"):
        dpg.add_menu_item(label="Import Data", callback=lambda: dpg.show_item(file_dialog_tag))

    with dpg.menu(label="Tools"):
        dpg.add_menu_item(label="Show About", callback=lambda: dpg.show_tool(dpg.mvTool_About))
        dpg.add_menu_item(label="Show Metrics", callback=lambda: dpg.show_tool(dpg.mvTool_Metrics))
        dpg.add_menu_item(label="Show Documentation", callback=lambda: dpg.show_tool(dpg.mvTool_Doc))
        dpg.add_menu_item(label="Show Debug", callback=lambda: dpg.show_tool(dpg.mvTool_Debug))
        dpg.add_menu_item(label="Show Style Editor", callback=lambda: dpg.show_tool(dpg.mvTool_Style))
        dpg.add_menu_item(label="Show Font Manager", callback=lambda: dpg.show_tool(dpg.mvTool_Font))
        dpg.add_menu_item(label="Show Item Registry", callback=lambda: dpg.show_tool(dpg.mvTool_ItemRegistry))

# Data series list
data_pool_window = dpg.add_window(label="Data Pool", height=650, width=400, user_data=list())


with dpg.window(label="Plot Window", pos=(420, 0), height=800, width=810):
    with dpg.group(horizontal=True):
        dpg.add_button(label="Split Horizontally")
        dpg.add_button(label="Split Vertically")
        dpg.add_button(label="Clear")

    with dpg.tab_bar(user_data={"act_tab": None, "act_plot": None, "plot_pages": 1}) as tab_bar:
        with dpg.tab(label=f"Plot {dpg.get_item_user_data(tab_bar)['plot_pages']}"):
            dpg.get_item_user_data(tab_bar)['act_tab'] = dpg.last_item()
            with dpg.subplots(rows=2, columns=2, no_title=True, height=600, width=800):
                dpg.get_item_user_data(tab_bar)['act_plot'] = dpg.last_item()

        dpg.add_tab_button(label="+", tag="Add Plot Button")

# --------------- Handlers -------------------

with dpg.handler_registry(tag="__demo_keyboard_handler"):  # show=True by default
    dpg.add_key_down_handler(key=dpg.mvKey_Control)
    dpg.add_key_release_handler(key=dpg.mvKey_Control)
    dpg.add_key_press_handler(key=dpg.mvKey_Control)
    dpg.add_key_down_handler(key=dpg.mvKey_Shift)
    dpg.add_key_release_handler(key=dpg.mvKey_Shift)
    dpg.add_key_press_handler(key=dpg.mvKey_Shift)

for handler in dpg.get_item_children("__demo_keyboard_handler", 1):
    dpg.set_item_callback(handler, eventHandler)

while dpg.is_dearpygui_running():
    # you can manually stop by using stop_dearpygui()
    dpg.render_dearpygui_frame()

# End
dpg.create_viewport(title='Custom Title', width=600, height=200)
dpg.setup_dearpygui();dpg.show_viewport();dpg.start_dearpygui();dpg.destroy_context()
# Out:
# 22
# 23
# 24
# 25
# 26
# 27
# 30
# 32
# 33
# 34
# 35
# 36
# 37
# 38
# 42
# 43
# 44
# 'Add Plot Button'
# 50
# 51
# 52
# 53
# 54
# 55
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Exception:
# Error:     [1005]
# Command:   get_item_info
# Item:      0
# Label:     Not found
# Item Type: Unknown
# Message:   Item not found: 0
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14288\2633269828.py in eventHandler(self, sender, data)
#       6 def eventHandler(self, sender, data):
#       7     # KeyDown data = [key, seconds]; KeyRelease data = key
# ----> 8     event_type = dpg.get_item_info(sender)["type"]
#       9     # print(data, type(data))
#      10     if event_type == "mvAppItemType::mvKeyDownHandler" and data[0] == dpg.mvKey_Control:
# ...

# %%
import dearpygui.dearpygui as dpg

dpg.create_context()
with dpg.window(label="Plot Window", pos=(420, 0), height=800, width=810):
    dpg.show_implot_demo()
    
dpg.create_viewport(title='Custom Title', width=600, height=200)
dpg.setup_dearpygui();dpg.show_viewport();dpg.start_dearpygui();dpg.destroy_context()

# %%
import dearpygui.dearpygui as dpg
from math import sin

dpg.create_context()

# creating data
sindatax = []
sindatay = []
for i in range(0, 500):
    sindatax.append(i / 1000)
    sindatay.append(0.5 + 0.5 * sin(50 * i / 1000))

with dpg.window(label="Tutorial"):
    # create plot
    with dpg.plot(label="Line Series", height=400, width=400):
        # optionally create legend
        dpg.add_plot_legend()

        # REQUIRED: create x and y axes
        dpg.add_plot_axis(dpg.mvXAxis, label="x")
        dpg.add_plot_axis(dpg.mvYAxis, label="y", tag="y_axis")

        # series belong to a y axis
        dpg.add_line_series(sindatax, sindatay, label="0.5 + 0.5 * sin(x)", parent="y_axis")

dpg.create_viewport(title='Custom Title', width=800, height=600)
dpg.setup_dearpygui()
dpg.show_viewport()
dpg.start_dearpygui()
dpg.destroy_context()
# Out:
# 23
# 24
# 'y_axis'
# 26

# %%
from dearpygui.dearpygui import *
import dearpygui.dearpygui as dpg


dpg.create_context()
dpg.create_viewport()
dpg.setup_dearpygui()

def tablePrinter(sender, data):
    print(sender, data)
    coordList = get_table_selections("Table Example")
    print("Selected Cells (coordinates): ", coordList)
    names = []
    for coordinates in coordList:
        names.append(get_table_item("Table Example", coordinates[0], coordinates[1]))
    print(names)

with dpg.window(label='MAIN_WINDOW') as ww_main:
    with dpg.table(header_row=True, callback=tablePrinter):
        dpg.add_table_column()
        dpg.add_table_column()
        dpg.add_table_column()
        for i in range(0, 4):
            with dpg.table_row():
                for j in range(0, 3):
                    dpg.add_text(f"Row{i} Column{j}")


dpg.show_viewport()
dpg.start_dearpygui()
dpg.destroy_context()
# Out:
# 23
# 24
# 25
# 27
# 28
# 29
# 31
# 32
# 33
# 35
# 36
# 37
# 39
# 40
# 41

# %%
import dearpygui.dearpygui as dpg

dpg.create_context()
dpg.create_viewport()
dpg.setup_dearpygui()

def sort_callback(sender, sort_specs, user_data):

    print(sender, sort_specs, user_data)
    
    # no sorting case
    if sort_specs is None: return

    rows = dpg.get_item_children(sender, 1)

    # create a list that can be sorted based on first cell
    # value, keeping track of row and value used to sort
    sortable_list = []
    for row in rows:
        first_cell = dpg.get_item_children(row, 1)[0]
        sortable_list.append([row, dpg.get_value(first_cell)])

    def _sorter(e):
        return e[1]

    sortable_list.sort(key=_sorter, reverse=sort_specs[0][1] < 0)

    # create list of just sorted row ids
    new_order = []
    for pair in sortable_list:
        new_order.append(pair[0])

    dpg.reorder_items(sender, 1, new_order)

def test(sender, app_data, user_data):
    print(sender, app_data, user_data, dpg.get_item_label(sender))
    
with dpg.window(label="Tutorial", width=500):
    with dpg.table(header_row=True, borders_innerH=True, borders_outerH=True,
                   borders_innerV=True, borders_outerV=True, row_background=True,
                   sortable=True, callback=sort_callback):

        dpg.add_table_column(label="One")
        dpg.add_table_column(label="Two", no_sort=True)

        for i in range(25):
            with dpg.table_row():
                dpg.add_input_int(label=" ", step=0, default_value=i)
                dpg.add_input_text(label=f"Cell {i}, 1", tag='cell_'+str(i), callback=test)

# main loop
dpg.show_viewport()
dpg.start_dearpygui()
dpg.destroy_context()
# Out:
# 23
# 24
# 26
# 'cell_0'
# 29
# 'cell_1'
# 32
# 'cell_2'
# 35
# 'cell_3'
# 38
# 'cell_4'
# 41
# 'cell_5'
# 44
# 'cell_6'
# 47
# 'cell_7'
# 50
# 'cell_8'
# 53
# 'cell_9'
# 56
# 'cell_10'
# 59
# 'cell_11'
# 62
# 'cell_12'
# 65
# 'cell_13'
# 68
# 'cell_14'
# 71
# 'cell_15'
# 74
# 'cell_16'
# 77
# 'cell_17'
# 80
# 'cell_18'
# 83
# 'cell_19'
# 86
# 'cell_20'
# 89
# 'cell_21'
# 92
# 'cell_22'
# 95
# 'cell_23'
# 98
# 'cell_24'
# 22 [[23, 1]] None
# cell_9 a None Cell 9, 1
# cell_9 af None Cell 9, 1
# cell_9 afg None Cell 9, 1
# cell_9 afgg None Cell 9, 1
# cell_9 afgge None Cell 9, 1
# cell_9 afggeg None Cell 9, 1
# cell_9 afggege None Cell 9, 1
# cell_9 afggegeg None Cell 9, 1
# cell_9 afggegegg None Cell 9, 1
# cell_9 afggegegge None Cell 9, 1
# cell_9 afggegeggeg None Cell 9, 1
